# %% [markdown]
# <a href="https://colab.research.google.com/github/TAKSAKI/-/blob/master/%E7%94%BB%E5%83%8F%E5%87%A6%E7%90%86%E7%AC%AC%E4%B8%89%E5%9B%9E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files 
x=files.upload()
# Out:
#      <input type="file" id="files-597c87cc-f96e-4aee-8859-662dbc4772a4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-597c87cc-f96e-4aee-8859-662dbc4772a4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 画像処理サンプル_IMG_4295.jpg to 画像処理サンプル_IMG_4295.jpg

# %%
uploaded_file_name = next(iter(x))
print(uploaded_file_name)
# Out:
# 画像処理サンプル_IMG_4295.jpg

# %%
import cv2
import numpy as np
src = cv2.imread(uploaded_file_name,0)
f = np.fft.fft2(src)
fshift = np.fft.fftshift(f)
fsrc = 50*np.log(np.abs(fshift))

# %%
from matplotlib import pyplot as plt

plt.imshow(fsrc)
